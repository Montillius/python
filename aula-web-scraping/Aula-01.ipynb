# %%
import requests

from bs4 import BeautifulSoup

# %%
url = "https://www.amazon.com.br/Notebook-Dell-G15-i1100-A30P-Gera%C3%A7%C3%A3o-Windows/dp/B09M92H7KN"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
page_text = response.text

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
inicio = page_text.find('a-price-whole')
page_text[inicio:]
# Out:
# 'a-price-whole">5.783<span class="a-price-decimal">,</span></span><span class="a-price-fraction">67</span></span></span>          </div>                                              </div>\n                        <div id="regulatoryDeposit_feature_div" class="celwidget" data-feature-name="regulatoryDeposit">\n                                                      </div>\n                           </div>\n                              <div id="desktop_qualifiedBuyBox" class="celwidget" data-feature-name="desktop_qualifiedBuyBox">\n                                                                                                                               <div class="a-section a-spacing-none a-padding-none">                           <div id="invitePlatform_feature_div" class="celwidget" data-feature-name="invitePlatform">\n                                                    </div>\n                              <div id="apex_offerDisplay_single_desktop" class="celwidget" data-featur
# ...

# %%
soup.find('span', {'a-price-whole'})
# Out:
# <span class="a-price-whole">5.783<span class="a-price-decimal">,</span></span>

# %%
soup.find('span', {'a-price-whole'}).text
# Out:
# '5.783,'
